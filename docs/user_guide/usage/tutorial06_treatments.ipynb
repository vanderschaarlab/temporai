# %% [markdown]
# [![Test In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vanderschaarlab/temporai/blob/main/tutorials/usage/tutorial06_treatments.ipynb)

# %% [markdown]
# # User Guide Tutorial 06: Treatment Effects
#
# This tutorial shows how to use TemporAI `treatments` plugins.

# %% [markdown]
# ## All `treatments` plugins
#
# > ⚠️ The `treatments` API is preliminary and likely to change.
#
# In the treatment effects estimation task, the goal is to predict a counterfactual outcome given an alternative treatment.
#
# To see all the relevant plugins:

# %%
from tempor.methods import plugin_loader
from rich.pretty import pprint

all_treatments_plugins = plugin_loader.list()["treatments"]

pprint(all_treatments_plugins, indent_guides=False)
# Out:
# {
#     'one_off': {'regression': ['synctwin_regressor']},
#     'temporal': {'classification': ['crn_classifier'], 'regression': ['crn_regressor']}
# }

# %% [markdown]
# ## Using a temporal treatment effects plugin.
#
# In this setting, the treatments are time series, and the outcomes are also time series.

# %%
from tempor.data.datasources import DummyTemporalTreatmentEffectsDataSource
from tempor.methods import plugin_loader

dataset = DummyTemporalTreatmentEffectsDataSource(
    random_state=42,
    temporal_covariates_missing_prob=0.0,
    temporal_treatments_n_features=1,
    temporal_treatments_n_categories=2,
).load()
print(dataset)

model = plugin_loader.get("treatments.temporal.regression.crn_regressor", epochs=20)
print(model)
# Out:
# TemporalTreatmentEffectsDataset(
#     time_series=TimeSeriesSamples([100, *, 5]),
#     static=StaticSamples([100, 3]),
#     predictive=TemporalTreatmentEffectsTaskData(
#         targets=TimeSeriesSamples([100, *, 2]),
#         treatments=TimeSeriesSamples([100, *, 1])
#     )
# )
# CRNTreatmentsRegressor(
#     name='crn_regressor',
#     category='treatments.temporal.regression',
#     plugin_type='method',
#     params={
#         'encoder_rnn_type': 'LSTM',
#         'encoder_hidden_size': 100,
#         'encoder_num_layers': 1,
#         'encoder_bias': True,
#         'encoder_dropout': 0.0,
#         'encoder_bidirectional': False,
#         'encoder_nonlinearity': None,
#         'encoder_proj_size': None,
#         'decoder_rnn_type': 'LSTM',
#         'decoder_hidden_size': 100,
#         'decoder_num_layers': 1,
#         'decoder_bias': True,
#         'decoder_dropout': 0.0,
#         'decoder_bidirectional': False,
#         'decoder_nonlinearity': None,
#         'decoder_proj_size': None,
#         'adapter_hidden_dims': [50],
#         'adapter_out_activation': 'Tanh',
#         'predictor_hidden_dims': [],
#         'predictor_out_activation': None,
#         'max_len': None,
#         'optimizer_str': 'Adam',
#         'optimizer_kwargs': {'lr': 0.01, 'weight_decay': 1e-05},
#         'batch_size': 32,
#         'epochs': 20,
#         'padding_indicator': -999.0
#     }
# )

# %%
# Targets:
dataset.predictive.targets
# Out:
# TimeSeriesSamples with data:
#                              0         1
# sample_idx time_idx
# 0          0         -3.110475 -3.566948
#            1          1.528495 -0.653673
#            2          2.275307 -0.695371
#            3          4.844060  3.469371
#            4          4.420301  5.147500
# ...                        ...       ...
# 99         7          5.994185  6.225290
#            8         10.913662  5.346697
#            9          9.558824  7.585175
#            10        10.194430  5.795619
#            11        13.774189  8.457336
#
# [1573 rows x 2 columns]

# %%
# Treatments:
dataset.predictive.treatments
# Out:
# TimeSeriesSamples with data:
#                      0
# sample_idx time_idx
# 0          0         0
#            1         1
#            2         1
#            3         0
#            4         0
# ...                 ..
# 99         7         1
#            8         1
#            9         0
#            10        0
#            11        1
#
# [1573 rows x 1 columns]

# %%
# Train.
model.fit(dataset);
# Out:
# Preparing data for decoder training...
# Preparing data for decoder training DONE.
# === Training stage: 1. Train encoder ===
# Epoch: 0, Prediction Loss: 73.011, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 73.011
# Epoch: 1, Prediction Loss: 36.266, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 36.266
# Epoch: 2, Prediction Loss: 22.669, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 22.669
# Epoch: 3, Prediction Loss: 18.582, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 18.582
# Epoch: 4, Prediction Loss: 18.174, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 18.174
# Epoch: 5, Prediction Loss: 14.973, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 14.973
# Epoch: 6, Prediction Loss: 10.067, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 10.067
# Epoch: 7, Prediction Loss: 7.859, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 7.859
# Epoch: 8, Prediction Loss: 6.596, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 6.596
# Epoch: 9, Prediction Loss: 5.638, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 5.638
# Epoch: 10, Prediction Loss: 5.010, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 5.010
# Epoch: 11, Prediction Loss: 4.577, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 4.577
# Epoch: 12, Prediction Loss: 4.508, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 4.508
# Epoch: 13, Prediction Loss: 4.170, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 4.170
# Epoch: 14, Prediction Loss: 4.026, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 4.026
# Epoch: 15, Prediction Loss: 3.952, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.952
# Epoch: 16, Prediction Loss: 3.894, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.894
# Epoch: 17, Prediction Loss: 3.823, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.823
# Epoch: 18, Prediction Loss: 3.799, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.799
# Epoch: 19, Prediction Loss: 3.831, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.831
# === Training stage: 2. Train decoder ===
# Epoch: 0, Prediction Loss: 33.018, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 33.018
# Epoch: 1, Prediction Loss: 5.067, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 5.067
# Epoch: 2, Prediction Loss: 3.862, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.862
# Epoch: 3, Prediction Loss: 3.849, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.849
# Epoch: 4, Prediction Loss: 3.793, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.793
# Epoch: 5, Prediction Loss: 3.784, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.784
# Epoch: 6, Prediction Loss: 3.706, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.706
# Epoch: 7, Prediction Loss: 3.674, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.674
# Epoch: 8, Prediction Loss: 3.744, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.744
# Epoch: 9, Prediction Loss: 3.659, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.659
# Epoch: 10, Prediction Loss: 3.657, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.657
# Epoch: 11, Prediction Loss: 3.763, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.763
# Epoch: 12, Prediction Loss: 3.733, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.733
# Epoch: 13, Prediction Loss: 3.711, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.711
# Epoch: 14, Prediction Loss: 3.688, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.688
# Epoch: 15, Prediction Loss: 3.658, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.658
# Epoch: 16, Prediction Loss: 3.627, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.627
# Epoch: 17, Prediction Loss: 3.646, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.646
# Epoch: 18, Prediction Loss: 3.682, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.682
# Epoch: 19, Prediction Loss: 3.645, Lambda: 1.000, Treatment BR Loss: 0.000, Loss: 3.645

# %%
# Predict counterfactuals:

import numpy as np

dataset = dataset[:5]

# Define horizons for each sample.
horizons = [tc.time_indexes()[0][len(tc.time_indexes()[0]) // 2 :] for tc in dataset.time_series]
print("Horizons for sample 0:\n", horizons[0], end="\n\n")

# Define treatment scenarios for each sample.
treatment_scenarios = [[np.asarray([1] * len(h)), np.asarray([0] * len(h))] for h in horizons]
print("Alternative treatment scenarios for sample 0:\n", treatment_scenarios[0], end="\n\n")

# Call predict_counterfactuals.
counterfactuals = model.predict_counterfactuals(dataset, horizons=horizons, treatment_scenarios=treatment_scenarios)
print("Counterfactual outcomes for sample 0, given the alternative treatment scenarios:\n")
for idx, c in enumerate(counterfactuals[0]):
    print(f"Treatment scenario {idx}, {treatment_scenarios[0][idx]}")
    print(c, end="\n\n")
# Out:
# Horizons for sample 0:
#  [5, 6, 7, 8, 9, 10]
#
# Alternative treatment scenarios for sample 0:
#  [array([1, 1, 1, 1, 1, 1]), array([0, 0, 0, 0, 0, 0])]
#
# Counterfactual outcomes for sample 0, given the alternative treatment scenarios:
#
# Treatment scenario 0, [1 1 1 1 1 1]
# TimeSeries() with data:
#                  0         1
# time_idx
# 5         6.428976  5.560657
# 6         6.545256  5.668885
# 7         6.552768  5.677176
# 8         6.553290  5.677758
# 9         6.553326  5.677799
# 10        6.553329  5.677802
#
# Treatment scenario 1, [0 0 0 0 0 0]
# TimeSeries() with data:
#                  0         1
# time_idx
# 5         6.781982  5.572202
# 6         6.910295  5.694051
# 7         6.917727  5.701763
# 8         6.918169  5.702227
# 9         6.918196  5.702255
# 10        6.918198  5.702257
